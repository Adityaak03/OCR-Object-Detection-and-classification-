# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rgmTaPEi8oKgUYhLb1EH")
project = rf.workspace("smoke-detection").project("smoke100-uwe4t")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Smoke100-4 in yolov8:: 100%|██████████| 43168/43168 [00:05<00:00, 8605.96it/s]

# %%
# !pip install ultralytics
from ultralytics import YOLO
model=YOLO('yolov8m.pt')
model.train(data='/kaggle/working/Smoke100-4/data.yaml',imgsz=640,epochs=20,save=True)
# Out:
# ...
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
model=YOLO('/kaggle/working/runs/detect/train4/weights/best.pt')
model.predict(source='/kaggle/input/smokevehiclevideo/You Never Want to See This Color Exhaust on Your Car.mp4',conf=0.4,save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1370) /kaggle/input/smokevehiclevideo/You Never Want to See This Color Exhaust on Your Car.mp4: 640x384 (no detections), 14.9ms
# video 1/1 (frame 2/1370) /kaggle/input/smokevehiclevideo/You Never Want to See This Color Exhaust on Your Car.mp4: 640x384 (no detections), 14.2ms
# ...
